# %% [markdown]
# # 로컬에서 이미지 생성

# %%
seed_number = 42

# !python3 generate.py --ckpt ./ckpt/pggan_512_v4/final.pt --out samples/sample_512_default_{seed_number}.png --n 16 --seed {seed_number}
# Out:
# Architecture: meta.generator_config (z_dim=512, max_res=512)
# Weights: G_ema_state  (21.34M params)
# Progressive generation: resolution=512, alpha=1.000
# Saved 16 samples → samples/sample_512_default_42.png

# %%
seed_number = 42

# !python3 generate.py --ckpt ./ckpt/pggan_512_v4_fine_tune/ckpt_002650320.pt --out samples/sample_512_fine_tune_{seed_number}.png --n 16 --seed {seed_number}
# Out:
# Architecture: meta.generator_config (z_dim=512, max_res=512)
# Weights: G_ema_state  (21.34M params)
# Progressive generation: resolution=512, alpha=1.000
# Saved 16 samples → samples/sample_512_fine_tune_42.png

# %%
seed_number = 42

# !python3 generate.py --ckpt ./ckpt/pggan_1024_v2/ckpt_001600352.pt --out samples/sample_1024_{seed_number}.png --n 4 --seed {seed_number}
# Out:
# python3(42488) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Architecture: meta.generator_config (z_dim=512, max_res=1024)
# Weights: G_ema_state  (21.37M params)
# Progressive generation: resolution=1024, alpha=1.000
# ^C
